# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# plan:
# start_poin = (7, -3, 4)
#         метод градиентного спуска -> находим минус градиент f
#             находим интервал унимодальности
#                 далее ищем min(f(x+a*p)) -> методом квадратичной интерполяции

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(x1,x2,x3=0):
    f = (x1 ** 4) + 22.0 * (x1 ** 3) + 181.5 * (x1 ** 2) + 665.5 * x1 + (x2 ** 2) - 1.4 * x2 
        + 3* (x3 ** 2) + 10.8 * x3 + 922.7725
    return f
# Out:
#   File "<ipython-input-4-01435f1f15f9>", line 3
#     + 3* (x3 ** 2) + 10.8 * x3 + 922.7725
#     ^
# IndentationError: unexpected indent

# %%
x = np.linspace(-10, 10,0.1)
y = np.linspace(-10, 10,0.1)

# %%
plt.contour(f(x,y),levels = 20)
plt.show()
